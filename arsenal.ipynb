# %%
for data in ['Dai', 'Fin', 'IT', 'Man']:
    for loss_fn in ['tweedie', 'l1', 'mse']:
        for k in [3]:
            for rank_weight in [0.1]:
                for con_weight in [0.05]:
                    for bias in ['yes']:
                        magic_cmd = f"""
                            # %%simple_training submit 
                            --work_dir=/group/ars-group-chenxi02/chenxi02/conferences/IJCAI24
                            --worker_img=harbor.weizhipin.com/business-pro/webide-image-lab-14:Transformer4.4.1-v4.1
                            --worker_cmd=sh scripts/train_task1.sh {data} 0 {k} {loss_fn} softplus 100.0 {rank_weight} {con_weight} yes {bias} {bias}
                            --cpu=8
                            --memory=80Gi
                            --gpu_type=A800
                            --tolerations=weizhipin.com/csl
                                """
                        define_node('train', magic_cmd=magic_cmd, is_overwrite=True)
                        exec_node('train', description = f"sh scripts/train_task1.sh {data} 0 {k} {loss_fn} softplus 100.0 {rank_weight} {con_weight} yes {bias} {bias}")

for data in ['Dai', 'Fin', 'IT', 'Man']:
    for loss_fn in ['tweedie']:
        for k in [3]:
            for rank_weight in [0.0]:
                for con_weight in [0.05]:
                    for bias in ['yes']:
                        magic_cmd = f"""
                            # %%simple_training submit 
                            --work_dir=/group/ars-group-chenxi02/chenxi02/conferences/IJCAI24
                            --worker_img=harbor.weizhipin.com/business-pro/webide-image-lab-14:Transformer4.4.1-v4.1
                            --worker_cmd=sh scripts/train_task1.sh {data} 0 {k} {loss_fn} softplus 100.0 {rank_weight} {con_weight} yes {bias} {bias}
                            --cpu=8
                            --memory=80Gi
                            --gpu_type=A800
                            --tolerations=weizhipin.com/csl
                                """
                        define_node('train', magic_cmd=magic_cmd, is_overwrite=True)
                        exec_node('train', description = f"sh scripts/train_task1.sh {data} 0 {k} {loss_fn} softplus 100.0 {rank_weight} {con_weight} yes {bias} {bias}")

for data in ['Dai', 'Fin', 'IT', 'Man']:
    for loss_fn in ['tweedie']:
        for k in [3]:
            for rank_weight in [1.0]:
                for con_weight in [0.0]:
                    for bias in ['yes']:
                        magic_cmd = f"""
                            # %%simple_training submit 
                            --work_dir=/group/ars-group-chenxi02/chenxi02/conferences/IJCAI24
                            --worker_img=harbor.weizhipin.com/business-pro/webide-image-lab-14:Transformer4.4.1-v4.1
                            --worker_cmd=sh scripts/train_task1.sh {data} 0 {k} {loss_fn} softplus 100.0 {rank_weight} {con_weight} yes {bias} {bias}
                            --cpu=8
                            --memory=80Gi
                            --gpu_type=A800
                            --tolerations=weizhipin.com/csl
                                """
                        define_node('train', magic_cmd=magic_cmd, is_overwrite=True)
                        exec_node('train', description = f"sh scripts/train_task1.sh {data} 0 {k} {loss_fn} softplus 100.0 {rank_weight} {con_weight} yes {bias} {bias}")

for data in ['Dai', 'Fin', 'IT', 'Man']:
    for loss_fn in ['tweedie']:
        for k in [3]:
            for rank_weight in [0.1]:
                for con_weight in [0.05]:
                    for bias in ['no']:
                        magic_cmd = f"""
                            # %%simple_training submit 
                            --work_dir=/group/ars-group-chenxi02/chenxi02/conferences/IJCAI24
                            --worker_img=harbor.weizhipin.com/business-pro/webide-image-lab-14:Transformer4.4.1-v4.1
                            --worker_cmd=sh scripts/train_task1.sh {data} 0 {k} {loss_fn} softplus 100.0 {rank_weight} {con_weight} yes {bias} {bias}
                            --cpu=8
                            --memory=80Gi
                            --gpu_type=A800
                            --tolerations=weizhipin.com/csl
                                """
                        define_node('train', magic_cmd=magic_cmd, is_overwrite=True)
                        exec_node('train', description = f"sh scripts/train_task1.sh {data} 0 {k} {loss_fn} softplus 100.0 {rank_weight} {con_weight} yes {bias} {bias}")
# Out:
# 2023-12-17 23:45:53.396 WARN [node_map.py:46] node_map_logger - the node name: train has been defined, will be overwrite the node.
# 2023-12-17 23:45:53.397 INFO [node_map.py:52] node_map_logger - success to add node: train
# 2023-12-17 23:45:53.413 INFO [graph.py:677] ArsenalGraph_logger - 开始发布任务
# 2023-12-17 23:45:53.561 INFO [graph.py:599] ArsenalGraph_logger - 任务提交成功，aflow_name: lab-14-magic-nhqsjj
# 2023-12-17 23:45:53.561 INFO [graph.py:679] ArsenalGraph_logger - 任务发布成功
# 2023-12-17 23:45:53.600 WARN [node_map.py:46] node_map_logger - the node name: train has been defined, will be overwrite the node.
# 2023-12-17 23:45:53.600 INFO [node_map.py:52] node_map_logger - success to add node: train
# 2023-12-17 23:45:53.618 INFO [graph.py:677] ArsenalGraph_logger - 开始发布任务
# 2023-12-17 23:45:53.754 INFO [graph.py:599] ArsenalGraph_logger - 任务提交成功，aflow_name: lab-14-magic-lkabzr
# 2023-12-17 23:45:53.755 INFO [graph.py:679] ArsenalGraph_logger - 任务发布成功
# ...

# %%
for data in ['Dai', 'Fin', 'IT', 'Man']:
    for diffweight in [1.0]:
        for adaptive in ['yes', 'no']:
            magic_cmd = f"""
                # %%simple_training submit 
                --work_dir=/group/ars-group-chenxi02/chenxi02/conferences/IJCAI24
                --worker_img=harbor.weizhipin.com/business-pro/webide-image-lab-14:Transformer4.4.1-v4.1
                --worker_cmd=sh scripts/train_task2.sh {data} 1.0 100.0 {diffweight} {adaptive}
                --cpu=16
                --memory=50Gi
                --gpu_type=A800
                --tolerations=weizhipin.com/csl
                    """
            define_node('train', magic_cmd=magic_cmd, is_overwrite=True)
            exec_node('train', description = f"sh scripts/train_task2.sh {data} 1.0 100.0 {diffweight} {adaptive}")

for data in ['Dai', 'Fin', 'IT', 'Man']:
    for diffweight in [0.0]:
        for adaptive in ['yes']:
            magic_cmd = f"""
                # %%simple_training submit 
                --work_dir=/group/ars-group-chenxi02/chenxi02/conferences/IJCAI24
                --worker_img=harbor.weizhipin.com/business-pro/webide-image-lab-14:Transformer4.4.1-v4.1
                --worker_cmd=sh scripts/train_task2.sh {data} 1.0 100.0 {diffweight} {adaptive}
                --cpu=16
                --memory=50Gi
                --gpu_type=A800
                --tolerations=weizhipin.com/csl
                    """
            define_node('train', magic_cmd=magic_cmd, is_overwrite=True)
            exec_node('train', description = f"sh scripts/train_task2.sh {data} 1.0 100.0 {diffweight} {adaptive}")
# Out:
# 2023-12-17 23:50:29.888 WARN [node_map.py:46] node_map_logger - the node name: train has been defined, will be overwrite the node.
# 2023-12-17 23:50:29.889 INFO [node_map.py:52] node_map_logger - success to add node: train
# 2023-12-17 23:50:29.909 INFO [graph.py:677] ArsenalGraph_logger - 开始发布任务
# 2023-12-17 23:50:30.069 INFO [graph.py:599] ArsenalGraph_logger - 任务提交成功，aflow_name: lab-14-magic-xagztd
# 2023-12-17 23:50:30.070 INFO [graph.py:679] ArsenalGraph_logger - 任务发布成功
# 2023-12-17 23:50:30.109 WARN [node_map.py:46] node_map_logger - the node name: train has been defined, will be overwrite the node.
# 2023-12-17 23:50:30.110 INFO [node_map.py:52] node_map_logger - success to add node: train
# 2023-12-17 23:50:30.127 INFO [graph.py:677] ArsenalGraph_logger - 开始发布任务
# 2023-12-17 23:50:30.323 INFO [graph.py:599] ArsenalGraph_logger - 任务提交成功，aflow_name: lab-14-magic-bjgsmx
# 2023-12-17 23:50:30.324 INFO [graph.py:679] ArsenalGraph_logger - 任务发布成功
# ...
