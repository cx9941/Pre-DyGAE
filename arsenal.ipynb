# %%
for data in ['Dai', 'Fin', 'IT', 'Man']:
    for loss_fn in ['tweedie', 'l1', 'mse']:
        for k in [3]:
            for rank_weight in [0.1]:
                for con_weight in [0.05]:
                    for bias in ['yes']:
                        magic_cmd = f"""
                            # %%simple_training submit 
                            --work_dir=/group/ars-group-chenxi02/chenxi02/conferences/IJCAI24
                            --worker_img=harbor.weizhipin.com/business-pro/webide-image-lab-14:Transformer4.4.1-v4.1
                            --worker_cmd=sh scripts/test_task1.sh {data} 0 {k} {loss_fn} softplus 100.0 {rank_weight} {con_weight} yes {bias} {bias}
                            --cpu=8
                            --memory=80Gi
                            --gpu_type=A800
                            --tolerations=weizhipin.com/csl
                                """
                        define_node('train', magic_cmd=magic_cmd, is_overwrite=True)
                        exec_node('train', description = f"sh scripts/test_task1.sh {data} 0 {k} {loss_fn} softplus 100.0 {rank_weight} {con_weight} yes {bias} {bias}")

for data in ['Dai', 'Fin', 'IT', 'Man']:
    for loss_fn in ['tweedie']:
        for k in [3]:
            for rank_weight in [0.0]:
                for con_weight in [0.05]:
                    for bias in ['yes']:
                        magic_cmd = f"""
                            # %%simple_training submit 
                            --work_dir=/group/ars-group-chenxi02/chenxi02/conferences/IJCAI24
                            --worker_img=harbor.weizhipin.com/business-pro/webide-image-lab-14:Transformer4.4.1-v4.1
                            --worker_cmd=sh scripts/test_task1.sh {data} 0 {k} {loss_fn} softplus 100.0 {rank_weight} {con_weight} yes {bias} {bias}
                            --cpu=8
                            --memory=80Gi
                            --gpu_type=A800
                            --tolerations=weizhipin.com/csl
                                """
                        define_node('train', magic_cmd=magic_cmd, is_overwrite=True)
                        exec_node('train', description = f"sh scripts/test_task1.sh {data} 0 {k} {loss_fn} softplus 100.0 {rank_weight} {con_weight} yes {bias} {bias}")

for data in ['Dai', 'Fin', 'IT', 'Man']:
    for loss_fn in ['tweedie']:
        for k in [3]:
            for rank_weight in [1.0]:
                for con_weight in [0.0]:
                    for bias in ['yes']:
                        magic_cmd = f"""
                            # %%simple_training submit 
                            --work_dir=/group/ars-group-chenxi02/chenxi02/conferences/IJCAI24
                            --worker_img=harbor.weizhipin.com/business-pro/webide-image-lab-14:Transformer4.4.1-v4.1
                            --worker_cmd=sh scripts/test_task1.sh {data} 0 {k} {loss_fn} softplus 100.0 {rank_weight} {con_weight} yes {bias} {bias}
                            --cpu=8
                            --memory=80Gi
                            --gpu_type=A800
                            --tolerations=weizhipin.com/csl
                                """
                        define_node('train', magic_cmd=magic_cmd, is_overwrite=True)
                        exec_node('train', description = f"sh scripts/test_task1.sh {data} 0 {k} {loss_fn} softplus 100.0 {rank_weight} {con_weight} yes {bias} {bias}")

for data in ['Dai', 'Fin', 'IT', 'Man']:
    for loss_fn in ['tweedie']:
        for k in [3]:
            for rank_weight in [0.1]:
                for con_weight in [0.05]:
                    for bias in ['no']:
                        magic_cmd = f"""
                            # %%simple_training submit 
                            --work_dir=/group/ars-group-chenxi02/chenxi02/conferences/IJCAI24
                            --worker_img=harbor.weizhipin.com/business-pro/webide-image-lab-14:Transformer4.4.1-v4.1
                            --worker_cmd=sh scripts/test_task1.sh {data} 0 {k} {loss_fn} softplus 100.0 {rank_weight} {con_weight} yes {bias} {bias}
INFO [graph.py:679] ArsenalGraph_logger - 任务发布成功

# %%
for data in ['Dai', 'Fin', 'IT', 'Man']:
    for diffweight in [1.0]:
        for adaptive in ['yes', 'no']:
            magic_cmd = f"""
                # %%simple_training submit 
                --work_dir=/group/ars-group-chenxi02/chenxi02/conferences/IJCAI24
                --worker_img=harbor.weizhipin.com/business-pro/webide-image-lab-14:Transformer4.4.1-v4.1
                --worker_cmd=sh scripts/train_task2.sh {data} 1.0 100.0 {diffweight} {adaptive}
                --cpu=16
                --memory=50Gi
                --gpu_type=A800
                --tolerations=weizhipin.com/csl
                    """
            define_node('train', magic_cmd=magic_cmd, is_overwrite=True)
            exec_node('train', description = f"sh scripts/train_task2.sh {data} 1.0 100.0 {diffweight} {adaptive}")

for data in ['Dai', 'Fin', 'IT', 'Man']:
    for diffweight in [0.0]:
        for adaptive in ['yes']:
            magic_cmd = f"""
                # %%simple_training submit 
                --work_dir=/group/ars-group-chenxi02/chenxi02/conferences/IJCAI24
                --worker_img=harbor.weizhipin.com/business-pro/webide-image-lab-14:Transformer4.4.1-v4.1
                --worker_cmd=sh scripts/train_task2.sh {data} 1.0 100.0 {diffweight} {adaptive}
                --cpu=16
                --memory=50Gi
                --gpu_type=A800
                --tolerations=weizhipin.com/csl
                    """
            define_node('train', magic_cmd=magic_cmd, is_overwrite=True)
            exec_node('train', description = f"sh scripts/train_task2.sh {data} 1.0 100.0 {diffweight} {adaptive}")
# Out:
# 2023-12-18 14:21:17.251 WARN [node_map.py:46] node_map_logger - the node name: train has been defined, will be overwrite the node.
# 2023-12-18 14:21:17.251 INFO [node_map.py:52] node_map_logger - success to add node: train
# 2023-12-18 14:21:17.270 INFO [graph.py:677] ArsenalGraph_logger - 开始发布任务
# 2023-12-18 14:21:17.390 INFO [graph.py:599] ArsenalGraph_logger - 任务提交成功，aflow_name: lab-14-magic-xjbhyk
# 2023-12-18 14:21:17.390 INFO [graph.py:679] ArsenalGraph_logger - 任务发布成功
# 2023-12-18 14:21:17.434 WARN [node_map.py:46] node_map_logger - the node name: train has been defined, will be overwrite the node.
# 2023-12-18 14:21:17.435 INFO [node_map.py:52] node_map_logger - success to add node: train
# 2023-12-18 14:21:17.452 INFO [graph.py:677] ArsenalGraph_logger - 开始发布任务
# 2023-12-18 14:21:17.579 INFO [graph.py:599] ArsenalGraph_logger - 任务提交成功，aflow_name: lab-14-magic-hnnwyx
# 2023-12-18 14:21:17.580 INFO [graph.py:679] ArsenalGraph_logger - 任务发布成功
# 2023-12-18 14:21:17.634 WARN [node_map.py:46] node_map_logger - the node name: train has been defined, will be overwrite the node.
# 2023-12-18 14:21:17.635 INFO [node_map.py:52] node_map_logger - success to add node: train
# 2023-12-18 14:21:17.662 INFO [graph.py:677] ArsenalGraph_logger - 开始发布任务
# 2023-12-18 14:21:17.824 INFO [graph.py:599] ArsenalGraph_logger - 任务提交成功，aflow_name: lab-14-magic-kbfsln
# 2023-12-18 14:21:17.825 INFO [graph.py:679] ArsenalGraph_logger - 任务发布成功
# 2023-12-18 14:21:17.881 WARN [node_map.py:46] node_map_logger - the node name: train has been defined, will be overwrite the node.
# 2023-12-18 14:21:17.882 INFO [node_map.py:52] node_map_logger - success to add node: train
# 2023-12-18 14:21:17.905 INFO [graph.py:677] ArsenalGraph_logger - 开始发布任务
# 2023-12-18 14:21:18.021 INFO [graph.py:599] ArsenalGraph_logger - 任务提交成功，aflow_name: lab-14-magic-rx8r0y
# 2023-12-18 14:21:18.022 INFO [graph.py:679] ArsenalGraph_logger - 任务发布成功
# 2023-12-18 14:21:18.060 WARN [node_map.py:46] node_map_logger - the node name: train has been defined, will be overwrite the node.
# 2023-12-18 14:21:18.061 INFO [node_map.py:52] node_map_logger - success to add node: train
# 2023-12-18 14:21:18.078 INFO [graph.py:677] ArsenalGraph_logger - 开始发布任务
# 2023-12-18 14:21:18.197 INFO [graph.py:599] ArsenalGraph_logger - 任务提交成功，aflow_name: lab-14-magic-fj15v4
# 2023-12-18 14:21:18.198 INFO [graph.py:679] ArsenalGraph_logger - 任务发布成功
# 2023-12-18 14:21:18.237 WARN [node_map.py:46] node_map_logger - the node name: train has been defined, will be overwrite the node.
# 2023-12-18 14:21:18.237 INFO [node_map.py:52] node_map_logger - success to add node: train
# 2023-12-18 14:21:18.255 INFO [graph.py:677] ArsenalGraph_logger - 开始发布任务
# 2023-12-18 14:21:18.359 INFO [graph.py:599] ArsenalGraph_logger - 任务提交成功，aflow_name: lab-14-magic-3gvgxy
# 2023-12-18 14:21:18.360 INFO [graph.py:679] ArsenalGraph_logger - 任务发布成功
# 2023-12-18 14:21:18.401 WARN [node_map.py:46] node_map_logger - the node name: train has been defined, will be overwrite the node.
# 2023-12-18 14:21:18.401 INFO [node_map.py:52] node_map_logger - success to add node: train
# 2023-12-18 14:21:18.418 INFO [graph.py:677] ArsenalGraph_logger - 开始发布任务
# 2023-12-18 14:21:18.564 INFO [graph.py:599] ArsenalGraph_logger - 任务提交成功，aflow_name: lab-14-magic-bwgqbf
# 2023-12-18 14:21:18.565 INFO [graph.py:679] ArsenalGraph_logger - 任务发布成功
# 2023-12-18 14:21:18.610 WARN [node_map.py:46] node_map_logger - the node name: train has been defined, will be overwrite the node.
# 2023-12-18 14:21:18.611 INFO [node_map.py:52] node_map_logger - success to add node: train
# 2023-12-18 14:21:18.629 INFO [graph.py:677] ArsenalGraph_logger - 开始发布任务
# 2023-12-18 14:21:18.750 INFO [graph.py:599] ArsenalGraph_logger - 任务提交成功，aflow_name: lab-14-magic-n8y2qv
# 2023-12-18 14:21:18.751 INFO [graph.py:679] ArsenalGraph_logger - 任务发布成功
# 2023-12-18 14:21:18.841 WARN [node_map.py:46] node_map_logger - the node name: train has been defined, will be overwrite the node.
# 2023-12-18 14:21:18.842 INFO [node_map.py:52] node_map_logger - success to add node: train
# 2023-12-18 14:21:18.871 INFO [graph.py:677] ArsenalGraph_logger - 开始发布任务
# 2023-12-18 14:21:19.021 INFO [graph.py:599] ArsenalGraph_logger - 任务提交成功，aflow_name: lab-14-magic-lm6xru
# 2023-12-18 14:21:19.021 INFO [graph.py:679] ArsenalGraph_logger - 任务发布成功
# 2023-12-18 14:21:19.065 WARN [node_map.py:46] node_map_logger - the node name: train has been defined, will be overwrite the node.
# 2023-12-18 14:21:19.065 INFO [node_map.py:52] node_map_logger - success to add node: train
# 2023-12-18 14:21:19.083 INFO [graph.py:677] ArsenalGraph_logger - 开始发布任务
# 2023-12-18 14:21:19.206 INFO [graph.py:599] ArsenalGraph_logger - 任务提交成功，aflow_name: lab-14-magic-g6znxa
# 2023-12-18 14:21:19.207 INFO [graph.py:679] ArsenalGraph_logger - 任务发布成功
# 2023-12-18 14:21:19.249 WARN [node_map.py:46] node_map_logger - the node name: train has been defined, will be overwrite the node.
# 2023-12-18 14:21:19.250 INFO [node_map.py:52] node_map_logger - success to add node: train
# 2023-12-18 14:21:19.271 INFO [graph.py:677] ArsenalGraph_logger - 开始发布任务
# 2023-12-18 14:21:19.386 INFO [graph.py:599] ArsenalGraph_logger - 任务提交成功，aflow_name: lab-14-magic-e0ltc6
# 2023-12-18 14:21:19.387 INFO [graph.py:679] ArsenalGraph_logger - 任务发布成功
# 2023-12-18 14:21:19.425 WARN [node_map.py:46] node_map_logger - the node name: train has been defined, will be overwrite the node.
# 2023-12-18 14:21:19.426 INFO [node_map.py:52] node_map_logger - success to add node: train
# 2023-12-18 14:21:19.444 INFO [graph.py:677] ArsenalGraph_logger - 开始发布任务
# 2023-12-18 14:21:19.563 INFO [graph.py:599] ArsenalGraph_logger - 任务提交成功，aflow_name: lab-14-magic-u4cvdx
# 2023-12-18 14:21:19.563 INFO [graph.py:679] ArsenalGraph_logger - 任务发布成功
